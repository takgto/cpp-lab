# %% [markdown]
# <a href="https://colab.research.google.com/github/takgto/cpp-lab/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 実習1: 複数ファイル構成とmake

# %%
![ -d cpp-lab ] || git clone https://github.com/takgto/cpp-lab.git
# %cd /content/cpp-lab/src
# !ls
# Out:
# Cloning into 'cpp-lab'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 15 (delta 1), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# Resolving deltas: 100% (1/1), done.
# /content/cpp-lab/src
# main.cpp  Makefile  util.cpp  util.h

# %%
# !ls -R /content/cpp-lab
# Out:
# /content/cpp-lab:
# lab1.ipynb  README.md  src
#
# /content/cpp-lab/src:
# main.cpp  Makefile  util.cpp  util.h

# %%
# !make && ./app
# Out:
# g++ -O2 -std=c++17 -Wall -c main.cpp
# g++ -O2 -std=c++17 -Wall -c util.cpp
# g++ -O2 -std=c++17 -Wall -o app main.o util.o
# 7
